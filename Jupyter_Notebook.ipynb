# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Shubham Tyagi**
#
# Data Scientist

# %% [markdown]
# *I am interested in data science because i would like to contribute towards preventing our wildlife and forests from threats like forest fire, poaching,deforetation and would like to contribute in healthcare in future.*

# %% [markdown]
# ### The below code will show a graph of y=x^2, which is a parabola

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
x=np.arange(-50,50)
y=x*x
plt.plot(x,y)
plt.title("Parabola")
plt.xlabel("x")
plt.ylabel("squares")
plt.show()

# %% [markdown]
# `print("hello")`
#
# ~~hello~~
#
# * Bar chart
# * Histogram
# * Pie chart
# * Box plot
#
# ### Data Science Tools
#
# 1. Apache Spark
# 2. MATLAB
# 3. Tableau
# 4. Jupyter
